# %% [markdown]
# <a href="https://colab.research.google.com/github/swarthyPig/SM13/blob/master/py_modules/py_modules_4_keras_tf2_cv_datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## CV (Computer vision) datasets in AI
# - from keras
#     - MNIST
#     - Fashion-MNIST
#     - CIFAR-10
#     - CIFAR-100

# %% [markdown]
# ### MNIST (Modified National Institute of Standards and Technology)
# - (60000, 28, 28), train
# - (10000, 28, 28), test
# - grayscale images of handwritten single digits between 0 and 9

# %%
# use TensorFlow 2.x 
# %tensorflow_version 2.x
# %tensorflow_version 1.x

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

print(tf.__version__)

# %%
from keras.datasets import mnist

# %%
# load dataset
(trainX, trainy), (testX, testy) = mnist.load_data()
# summarize loaded dataset
print('Train: X=%s, y=%s' % (trainX.shape, trainy.shape))
print('Test: X=%s, y=%s' % (testX.shape, testy.shape))

# %%
# plot first few images
for i in range(9):
	# define subplot
	plt.subplot(330 + 1 + i)
	# plot raw pixel data
	plt.imshow(trainX[i], cmap=plt.get_cmap('gray'))
# show the figure
# plt.show()

# %% [markdown]
# ### train

# %%
import numpy as np

index, count = np.unique(trainy, return_counts=True)

mnist_train_dic = dict(zip(index, count))
mnist_train_dic
# Out:
# {0: 6000,
#  1: 6000,
#  2: 6000,
#  3: 6000,
#  4: 6000,
#  5: 6000,
#  6: 6000,
#  7: 6000,
#  8: 6000,
#  9: 6000}

# %%
plt.bar(list(mnist_train_dic.keys()),mnist_train_dic.values(), color = 'g')
# Out:
# <BarContainer object of 10 artists>

# %%
fig = plt.figure(figsize=(10,6))

for i in range(10):
    plt.subplot(2,5,i+1)
    num0_9 = trainX[trainy == i]
    plt.imshow(num0_9[0], cmap = 'gray')
    plt.title("Class %d" % (i))
    plt.xticks([])
    plt.yticks([])

# %% [markdown]
# ### test

# %%
import numpy as np

index_test, count_test = np.unique(testy, return_counts=True)

mnist_test_dic = dict(zip(index_test, count_test))
mnist_test_dic
# Out:
# {0: 1000,
#  1: 1000,
#  2: 1000,
#  3: 1000,
#  4: 1000,
#  5: 1000,
#  6: 1000,
#  7: 1000,
#  8: 1000,
#  9: 1000}

# %%
plt.bar(list(mnist_test_dic.keys()),mnist_test_dic.values(), color = 'g')
# Out:
# <BarContainer object of 10 artists>

# %%
fig = plt.figure(figsize=(10,6))

for i in range(10):
    plt.subplot(2,5,i+1)
    num0_9 = testX[testy == i]
    plt.imshow(num0_9[0], cmap = 'gray')
    plt.title("Class %d" % (i))
    plt.xticks([])
    plt.yticks([])

# %% [markdown]
# ### Fashion-MNIST Dataset
# - (60000, 28, 28), train
# - (10000, 28, 28), test
# - grayscale images of items of 10 types of clothing, such as shoes, t-shirts, dresses, and more.

# %%
from keras.datasets import fashion_mnist
# load dataset
(trainX, trainy), (testX, testy) = fashion_mnist.load_data()
# summarize loaded dataset
print('Train: X=%s, y=%s' % (trainX.shape, trainy.shape))
print('Test: X=%s, y=%s' % (testX.shape, testy.shape))

# %%
# plot first few images
for i in range(9):
	# define subplot
	plt.subplot(330 + 1 + i)
	# plot raw pixel data
	plt.imshow(trainX[i], cmap=plt.get_cmap('gray'))
# show the figure
# plt.show()

# %% [markdown]
# ### train

# %%
import numpy as np

index, count = np.unique(trainy, return_counts=True)

mnist_train_dic = dict(zip(index, count))
mnist_train_dic
# Out:
# {0: 6000,
#  1: 6000,
#  2: 6000,
#  3: 6000,
#  4: 6000,
#  5: 6000,
#  6: 6000,
#  7: 6000,
#  8: 6000,
#  9: 6000}

# %%
plt.bar(list(mnist_train_dic.keys()),mnist_train_dic.values(), color = 'g')
# Out:
# <BarContainer object of 10 artists>

# %%
fig = plt.figure(figsize=(10,6))

for i in range(10):
    plt.subplot(2,5,i+1)
    num0_9 = trainX[trainy == i]
    plt.imshow(num0_9[0], cmap = 'gray')
    plt.title("Class %d" % (i))
    plt.xticks([])
    plt.yticks([])

# %% [markdown]
# ### test

# %%
import numpy as np

index, count = np.unique(testy, return_counts=True)

mnist_test_dic = dict(zip(index, count))
mnist_test_dic
# Out:
# {0: 6000,
#  1: 6000,
#  2: 6000,
#  3: 6000,
#  4: 6000,
#  5: 6000,
#  6: 6000,
#  7: 6000,
#  8: 6000,
#  9: 6000}

# %%
plt.bar(list(mnist_test_dic.keys()),mnist_test_dic.values(), color = 'g')
# Out:
# <BarContainer object of 10 artists>

# %%
fig = plt.figure(figsize=(10,6))

for i in range(10):
    plt.subplot(2,5,i+1)
    num0_9 = testX[testy == i]
    plt.imshow(num0_9[0], cmap = 'gray')
    plt.title("Class %d" % (i))
    plt.xticks([])
    plt.yticks([])

# %% [markdown]
# ### CIFAR-10 Dataset (CIFAR: Canadian Institute For Advanced Research)
# - (50000, 32, 32), train
# - (10000, 32, 32) test
# - color photographs of objects from 10 classes, such as frogs, birds, cats, ships, etc

# %%
from keras.datasets import cifar10
# load dataset
(trainX, trainy), (testX, testy) = cifar10.load_data()
# summarize loaded dataset
print('Train: X=%s, y=%s' % (trainX.shape, trainy.shape))
print('Test: X=%s, y=%s' % (testX.shape, testy.shape))

# %%
# plot first few images
for i in range(9):
	# define subplot
	plt.subplot(330 + 1 + i)
	# plot raw pixel data
	plt.imshow(trainX[i])
# show the figure
# plt.show()

# %% [markdown]
# ### train

# %%
import numpy as np

index, count = np.unique(trainy, return_counts=True)

cifar10_train_dic = dict(zip(index, count))
cifar10_train_dic
# Out:
# {0: 5000,
#  1: 5000,
#  2: 5000,
#  3: 5000,
#  4: 5000,
#  5: 5000,
#  6: 5000,
#  7: 5000,
#  8: 5000,
#  9: 5000}

# %%
plt.bar(list(cifar10_train_dic.keys()),cifar10_train_dic.values(), color = 'g')
# Out:
# <BarContainer object of 10 artists>

# %%
fig = plt.figure(figsize=(10,6))

for i in range(10):
    plt.subplot(2,5,i+1)
    num0_9 = trainX[trainy[:,0] == i]
    plt.imshow(num0_9[0], cmap = 'gray')
    plt.title("Class %d" % (i))
    plt.xticks([])
    plt.yticks([])

# %% [markdown]
# ### test

# %%
import numpy as np

index_test, count_test = np.unique(testy, return_counts=True)

cifar10_test_dic = dict(zip(index_test, count_test))
cifar10_test_dic
# Out:
# {0: 5000,
#  1: 5000,
#  2: 5000,
#  3: 5000,
#  4: 5000,
#  5: 5000,
#  6: 5000,
#  7: 5000,
#  8: 5000,
#  9: 5000}

# %%
plt.bar(list(cifar10_test_dic.keys()),cifar10_test_dic.values(), color = 'g')
# Out:
# <BarContainer object of 10 artists>

# %%
fig = plt.figure(figsize=(10,6))

for i in range(10):
    plt.subplot(2,5,i+1)
    num0_9 = testX[testy[:,0] == i]
    plt.imshow(num0_9[0], cmap = 'gray')
    plt.title("Class %d" % (i))
    plt.xticks([])
    plt.yticks([])

# %% [markdown]
# ### CIFAR-100 Dataset (CIFAR: Canadian Institute For Advanced Research)
# - (50000, 32, 32), train
# - (10000, 32, 32) test
# - color photographs of objects from 100 classes, such as fish, flowers, insects, and much more

# %%
from keras.datasets import cifar100
# load dataset
(trainX, trainy), (testX, testy) = cifar100.load_data()
# summarize loaded dataset
print('Train: X=%s, y=%s' % (trainX.shape, trainy.shape))
print('Test: X=%s, y=%s' % (testX.shape, testy.shape))

# %%
# plot first few images
for i in range(10):
	# define subplot
	plt.subplot(2,5, 1 + i)
	# plot raw pixel data
	plt.imshow(trainX[i])
# show the figure
# plt.show()

# %% [markdown]
# ### train

# %%
import numpy as np

index, count = np.unique(trainy, return_counts=True)

cifar100_train_dic = dict(zip(index, count))
cifar100_train_dic
# Out:
# {0: 500,
#  1: 500,
#  2: 500,
#  3: 500,
#  4: 500,
#  5: 500,
#  6: 500,
#  7: 500,
#  8: 500,
#  9: 500,
#  10: 500,
#  11: 500,
#  12: 500,
#  13: 500,
#  14: 500,
#  15: 500,
#  16: 500,
#  17: 500,
#  18: 500,
#  19: 500,
#  20: 500,
#  21: 500,
#  22: 500,
#  23: 500,
#  24: 500,
#  25: 500,
#  26: 500,
#  27: 500,
#  28: 500,
#  29: 500,
#  30: 500,
#  31: 500,
#  32: 500,
#  33: 500,
#  34: 500,
#  35: 500,
#  36: 500,
#  37: 500,
#  38: 500,
#  39: 500,
#  40: 500,
#  41: 500,
#  42: 500,
#  43: 500,
#  44: 500,
#  45: 500,
#  46: 500,
#  47: 500,
#  48: 500,
#  49: 500,
#  50: 500,
#  51: 500,
#  52: 500,
#  53: 500,
#  54: 500,
#  55: 500,
#  56: 500,
#  57: 500,
#  58: 500,
#  59: 500,
#  60: 500,
#  61: 500,
#  62: 500,
#  63: 500,
#  64: 500,
#  65: 500,
#  66: 500,
#  67: 500,
#  68: 500,
#  69: 500,
#  70: 500,
#  71: 500,
#  72: 500,
#  73: 500,
#  74: 500,
#  75: 500,
#  76: 500,
#  77: 500,
#  78: 500,
#  79: 500,
#  80: 500,
#  81: 500,
#  82: 500,
#  83: 500,
#  84: 500,
#  85: 500,
#  86: 500,
#  87: 500,
#  88: 500,
#  89: 500,
#  90: 500,
#  91: 500,
#  92: 500,
#  93: 500,
#  94: 500,
#  95: 500,
#  96: 500,
#  97: 500,
#  98: 500,
#  99: 500}

# %%
plt.bar(list(cifar100_train_dic.keys()),cifar100_train_dic.values(), color = 'g')
# Out:
# <BarContainer object of 100 artists>

# %%
fig = plt.figure(figsize=(12,15))

for i in range(100):
    plt.subplot(10,10,i+1)
    num0_9 = trainX[trainy[:,0] == i]
    plt.imshow(num0_9[0], cmap = 'gray')
    plt.title("Class %d" % (i))
    plt.xticks([])
    plt.yticks([])

# %% [markdown]
# ### test

# %%
import numpy as np

index_test, count_test = np.unique(testy, return_counts=True)

cifar100_test_dic = dict(zip(index, count))
cifar100_test_dic
# Out:
# {0: 500,
#  1: 500,
#  2: 500,
#  3: 500,
#  4: 500,
#  5: 500,
#  6: 500,
#  7: 500,
#  8: 500,
#  9: 500,
#  10: 500,
#  11: 500,
#  12: 500,
#  13: 500,
#  14: 500,
#  15: 500,
#  16: 500,
#  17: 500,
#  18: 500,
#  19: 500,
#  20: 500,
#  21: 500,
#  22: 500,
#  23: 500,
#  24: 500,
#  25: 500,
#  26: 500,
#  27: 500,
#  28: 500,
#  29: 500,
#  30: 500,
#  31: 500,
#  32: 500,
#  33: 500,
#  34: 500,
#  35: 500,
#  36: 500,
#  37: 500,
#  38: 500,
#  39: 500,
#  40: 500,
#  41: 500,
#  42: 500,
#  43: 500,
#  44: 500,
#  45: 500,
#  46: 500,
#  47: 500,
#  48: 500,
#  49: 500,
#  50: 500,
#  51: 500,
#  52: 500,
#  53: 500,
#  54: 500,
#  55: 500,
#  56: 500,
#  57: 500,
#  58: 500,
#  59: 500,
#  60: 500,
#  61: 500,
#  62: 500,
#  63: 500,
#  64: 500,
#  65: 500,
#  66: 500,
#  67: 500,
#  68: 500,
#  69: 500,
#  70: 500,
#  71: 500,
#  72: 500,
#  73: 500,
#  74: 500,
#  75: 500,
#  76: 500,
#  77: 500,
#  78: 500,
#  79: 500,
#  80: 500,
#  81: 500,
#  82: 500,
#  83: 500,
#  84: 500,
#  85: 500,
#  86: 500,
#  87: 500,
#  88: 500,
#  89: 500,
#  90: 500,
#  91: 500,
#  92: 500,
#  93: 500,
#  94: 500,
#  95: 500,
#  96: 500,
#  97: 500,
#  98: 500,
#  99: 500}

# %%
plt.bar(list(cifar100_test_dic.keys()),cifar100_test_dic.values(), color = 'g')
# Out:
# <BarContainer object of 100 artists>

# %%
# plot first few images

fig = plt.figure(figsize=(12,15))

for i in range(100):
    plt.subplot(10,10,i+1)
    num0_9 = testX[testy[:,0] == i]
    plt.imshow(num0_9[0], cmap = 'gray')
    plt.title("Class %d" % (i))
    plt.xticks([])
    plt.yticks([])

# %% [markdown]
# #### [도전} CIFAR-100의 첫 20개의 사진을 그려보시오.

# %%
# plot first 20 images

fig = plt.figure(figsize=(12,15))

for i in range(20):
    plt.subplot(4,5,i+1)
    num0_9 = trainX[trainy[:,0] == i]
    plt.imshow(num0_9[0], cmap = 'gray')
    plt.title("Class %d" % (i))
    plt.xticks([])
    plt.yticks([])

# %% [markdown]
# ## What is your dataset?
